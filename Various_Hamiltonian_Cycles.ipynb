# %% [markdown]
# # Hamiltonian Cycles with Various Graphs
# This section shows the algorithm doing its thing on various famous graphs. Most, if not all, of the graphs have their own page on Wikipedia page.

# %%
from hamiltonian_paths import HamPath
import time

# %%
G = graphs.GrotzschGraph()
G.show()
g = HamPath(G)
t1 = time.time()
p= g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2=time.time()
p.show()
print(t2-t1)
# Out:
# Graphics object consisting of 32 graphics primitives
# The algorithm took 1 tries
# Graphics object consisting of 32 graphics primitives
# 0.004551887512207031

# %%
G = graphs.BrinkmannGraph()
g = HamPath(G)
g.G.show()
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show()
print(t2-t1)
# Out:
# Graphics object consisting of 64 graphics primitives
# The algorithm took 10 tries
# Graphics object consisting of 64 graphics primitives
# 0.05372786521911621

# %%
G = graphs.FranklinGraph()
g = HamPath(G)
g.G.show()
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show()
print(t2-t1)
# Out:
# Graphics object consisting of 31 graphics primitives
# The algorithm took 10 tries
# Graphics object consisting of 31 graphics primitives
# 0.023972749710083008

# %%
G = graphs.FruchtGraph()
g = HamPath(G)
g.G.show()
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show()
print(t2-t1)
# Out:
# Graphics object consisting of 31 graphics primitives
# The algorithm took 56 tries
# Graphics object consisting of 31 graphics primitives
# 0.08141493797302246

# %%
G = graphs.GolombGraph()
g = HamPath(G)
g.G.show()
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show()
print(t2-t1)
# Out:
# Graphics object consisting of 29 graphics primitives
# The algorithm took 221 tries
# Graphics object consisting of 29 graphics primitives
# 0.2611362934112549

# %%
G = graphs.HeawoodGraph()
g = HamPath(G)
g.G.show()
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show()
print(t2-t1)
# Out:
# Graphics object consisting of 36 graphics primitives
# The algorithm took 3 tries
# Graphics object consisting of 36 graphics primitives
# 0.008674383163452148

# %%
G = graphs.HoffmanGraph()
g = HamPath(G)
g.G.show()
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show()
print(t2-t1)
# Out:
# Graphics object consisting of 49 graphics primitives
# The algorithm took 6 tries
# Graphics object consisting of 49 graphics primitives
# 0.02138042449951172

# %%
G = graphs.MoebiusKantorGraph()
g = HamPath(G)
g.G.show()
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show()
print(t2-t1)
# Out:
# Graphics object consisting of 41 graphics primitives
# The algorithm took 20 tries
# Graphics object consisting of 41 graphics primitives
# 0.04826784133911133

# %%
G = graphs.MoserSpindle()
g = HamPath(G)
g.G.show()
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show()
print(t2-t1)
# Out:
# Graphics object consisting of 19 graphics primitives
# The algorithm took 8 tries
# Graphics object consisting of 19 graphics primitives
# 0.013228416442871094

# %%
G = graphs.RobertsonGraph()
g = HamPath(G)
g.G.show()
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show()
print(t2-t1)
# Out:
# Graphics object consisting of 58 graphics primitives
# The algorithm took 49 tries
# Graphics object consisting of 58 graphics primitives
# 0.17783665657043457

# %%
G = graphs.ShrikhandeGraph()
g = HamPath(G)
g.G.show()
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show()
print(t2-t1)
# Out:
# Graphics object consisting of 65 graphics primitives
# The algorithm took 2 tries
# Graphics object consisting of 65 graphics primitives
# 0.014797210693359375

# %%
#Using 4 instead of 3 takes a lot longer
G = graphs.SierpinskiGasketGraph(3)
g = HamPath(G)
g.G.show(figsize=10)
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show(figsize=10)
print(t2-t1)
# Out:
# Graphics object consisting of 43 graphics primitives
# The algorithm took 87 tries
# Graphics object consisting of 43 graphics primitives
# 0.0888679027557373

# %%
G = graphs.DyckGraph()
g = HamPath(G)
g.G.show()
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show()
print(t2-t1)
# Out:
# Graphics object consisting of 81 graphics primitives
# The algorithm took 499 tries
# Graphics object consisting of 81 graphics primitives
# 1.9981052875518799

# %%
#This one takes a while...
G = graphs.FosterGraph()
g = HamPath(G)
g.G.show()
t1 = time.time()
p = g.ham_path_plot(algorithm=2, cycle=True, new=False)
t2 = time.time()
p.show(figsize=15)
print(t2-t1)
# Out:
# Graphics object consisting of 226 graphics primitives
